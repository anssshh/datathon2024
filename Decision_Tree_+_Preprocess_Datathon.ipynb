# %% [markdown]
# ##**Import Libraries**

# %%
import pandas as pd
import numpy as np

# %%
# !pip install ydata-profiling
from ydata_profiling import ProfileReport
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.5/359.5 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 11.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 28.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 28.1 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27080 sha256=3ea1a59a10ebd243effad5909696ee854414764630bd361aafdb72b30c33201b
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ##**Import Datasets**

# %% [markdown]
# ###loan_activities

# %%
loan_activities = pd.read_csv('/content/drive/My Drive/PROJECT/DATATHON/DATASET/loan_activities.csv', sep=',')

# %%
loan_activities.head()

# %%
loan_activities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4300999 entries, 0 to 4300998
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   user_id            int64
#  1   reference_contact  int64
#  2   loan_type          int64
#  3   ts                 int64
# dtypes: int64(4)
# memory usage: 131.3 MB

# %%
profile = ProfileReport(loan_activities)
profile.to_file(output_file='loan_activities.html')
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
loan_activities[loan_activities['reference_contact']==2698864]
# Out:
#          user_id  reference_contact  loan_type   ts
# 1920902  1173580            2698864          5  432

# %%
copyla = loan_activities.copy()

# %% [markdown]
# ###non_borrower_user

# %%
non_borrower_user = pd.read_csv('/content/drive/My Drive/PROJECT/DATATHON/DATASET/non_borrower_user.csv', sep=',')

# %%
non_borrower_user.head()
# Out:
#    user_id  pc0  pc1   pc2    pc3       pc4  pc5    pc6   pc7    pc8  \
# 0        0    1    5 -1.00 -1.000 -1.000000 -1.0 -1.000 -1.00 -1.000
# 1        1    0    8  0.63  0.565  0.896825  0.6  2.298  0.21  2.284
# 2        2   -1   -1 -1.00 -1.000 -1.000000 -1.0 -1.000 -1.00 -1.000
# 3        6    0    1 -1.00 -1.000 -1.000000 -1.0 -1.000 -1.00 -1.000
# 4        7    1    6 -1.00 -1.000 -1.000000 -1.0 -1.000 -1.00 -1.000
#
#         pc9  pc10      pc11      pc12      pc13  pc14      pc15      pc16
# 0 -1.000000     0 -1.000000 -1.000000 -1.000000  -1.0 -1.000000 -1.000000
# 1  0.993908     1  0.103175  0.006092  0.053097   1.0  0.007937  0.166667
# 2 -1.000000     0 -1.000000 -1.000000 -1.000000  -1.0 -1.000000 -1.000000
# 3 -1.000000     0 -1.000000 -1.000000 -1.000000  -1.0 -1.000000 -1.000000
# 4 -1.000000     0 -1.000000 -1.000000 -1.000000  -1.0 -1.000000 -1.000000

# %%
non_borrower_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 18 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   user_id  1048575 non-null  int64
#  1   pc0      1048575 non-null  int64
#  2   pc1      1048575 non-null  int64
#  3   pc2      1048575 non-null  float64
#  4   pc3      1048575 non-null  float64
#  5   pc4      1048575 non-null  float64
#  6   pc5      1048575 non-null  float64
#  7   pc6      1048575 non-null  float64
#  8   pc7      1048575 non-null  float64
#  9   pc8      1048575 non-null  float64
#  10  pc9      1048575 non-null  float64
#  11  pc10     1048575 non-null  int64
#  12  pc11     1048575 non-null  float64
#  13  pc12     1048575 non-null  float64
#  14  pc13     1048575 non-null  float64
#  15  pc14     1048575 non-null  float64
#  16  pc15     1048575 non-null  float64
#  17  pc16     1048575 non-null  float64
# dtypes: float64(14), int64(4)
# ...

# %%
copynbu = non_borrower_user.copy()

# %% [markdown]
# ###train

# %%
train = pd.read_csv('/content/drive/My Drive/PROJECT/DATATHON/DATASET/train.csv', sep=',')

# %%
train.head()
# Out:
#    user_id  pc0  pc1    pc2    pc3       pc4  pc5    pc6    pc7    pc8  \
# 0        3  1.0  1.0  0.275  0.255  0.927273  0.4  0.260  0.040  0.254
# 1        5  0.0  0.0  0.430  0.365  0.848837  0.4  1.253  0.210  1.235
# 2        9  1.0  3.0  1.315  0.825  0.627376  0.9  2.385  0.128  2.270
# 3       10  0.0  5.0 -1.000 -1.000 -1.000000 -1.0 -1.000 -1.000 -1.000
# 4       17  1.0  1.0  0.235  0.160  0.680851  0.1  0.120  0.002  0.104
#
#         pc9  pc10      pc11      pc12      pc13      pc14      pc15      pc16  \
# 0  0.976923   1.0  0.072727  0.023077  0.078431  0.750000  0.018182  0.250000
# 1  0.985634   1.0  0.151163  0.014366  0.054795  0.500000  0.011628  0.250000
# 2  0.951782   1.0  0.372624  0.048218  0.054545  0.777778  0.003802  0.111111
# 3 -1.000000   0.0 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 4  0.866667   0.0  0.319149  0.133333  0.031250 -1.000000 -1.000000 -1.000000
#
#    label
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857899 entries, 0 to 857898
# Data columns (total 19 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   user_id  857899 non-null  int64
#  1   pc0      857899 non-null  float64
#  2   pc1      857899 non-null  float64
#  3   pc2      857899 non-null  float64
#  4   pc3      857899 non-null  float64
#  5   pc4      857899 non-null  float64
#  6   pc5      857899 non-null  float64
#  7   pc6      857899 non-null  float64
#  8   pc7      857899 non-null  float64
#  9   pc8      857899 non-null  float64
#  10  pc9      857899 non-null  float64
#  11  pc10     857899 non-null  float64
#  12  pc11     857899 non-null  float64
#  13  pc12     857899 non-null  float64
#  14  pc13     857899 non-null  float64
#  15  pc14     857899 non-null  float64
#  16  pc15     857899 non-null  float64
#  17  pc16     857899 non-null  float64
#  18  label    857899 non-null  int64
# ...

# %%
profile = ProfileReport(train, title='train.csv Profiling')
profile.to_file(output_file='train.html')
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
copytrain = train.copy()

# %%
train[train['label']==1]
# Out:
#         user_id  pc0  pc1    pc2    pc3       pc4  ...      pc12      pc13  pc14      pc15  pc16  label
# 252        1080  1.0  2.0 -1.000 -1.000 -1.000000  ... -1.000000 -1.000000 -1.00 -1.000000 -1.00      1
# 305        1307  1.0  1.0  0.295  0.285  0.966102  ...  0.005780  0.087719  1.00 -1.000000 -1.00      1
# 481        2001  0.0  1.0  0.490  0.455  0.928571  ...  0.009560  0.043956  0.75  0.010204  0.25      1
# 482        2002  1.0  1.0 -1.000 -1.000 -1.000000  ... -1.000000 -1.000000 -1.00 -1.000000 -1.00      1
# 515        2129  1.0  5.0 -1.000 -1.000 -1.000000  ... -1.000000 -1.000000 -1.00 -1.000000 -1.00      1
# ...         ...  ...  ...    ...    ...       ...  ...       ...       ...   ...       ...   ...    ...
# 857668  3699581  1.0  2.0 -1.000 -1.000 -1.000000  ... -1.000000 -1.000000 -1.00 -1.000000 -1.00      1
# 857678  3699636  1.0  5.0 -1.000 -1.000 -1.000000  ... -1.000000 -1.000000 -1.00 -1.000000 -1.00      1
# ...

# %%
train[train['user_id']==1927927]
# Out:
# Empty DataFrame
# Columns: [user_id, pc0, pc1, pc2, pc3, pc4, pc5, pc6, pc7, pc8, pc9, pc10, pc11, pc12, pc13, pc14, pc15, pc16, label]
# Index: []

# %%
loan_activities[loan_activities['reference_contact']==470352]
# Out:
#          user_id  reference_contact  loan_type   ts
# 473922   1369728             470352          3  231
# 3952306  3377462             470352         10  233
# 3952509  3698995             470352         10  236
# 3952570    94492             470352         10  234
# 3952582  1353527             470352         10  235
# ...          ...                ...        ...  ...
# 4207495  1927927             470352         10  235
# 4207502  1559551             470352         10  234
# 4208104   508889             470352         10  235
# 4213062   508589             470352         10  235
# 4213282  1964745             470352         10  234
#
# [882 rows x 4 columns]

# %% [markdown]
# ##**Data Preprocessing**

# %% [markdown]
# ###Bersihkan Data Null

# %%
loan_activities.isnull().sum()
# Out:
# user_id              0
# reference_contact    0
# loan_type            0
# ts                   0
# dtype: int64

# %%
non_borrower_user.isnull().sum()
# Out:
# user_id    0
# pc0        0
# pc1        0
# pc2        0
# pc3        0
# pc4        0
# pc5        0
# pc6        0
# pc7        0
# pc8        0
# pc9        0
# pc10       0
# pc11       0
# pc12       0
# pc13       0
# pc14       0
# pc15       0
# pc16       0
# dtype: int64

# %%
train.isnull().sum()
# Out:
# user_id    0
# pc0        0
# pc1        0
# pc2        0
# pc3        0
# pc4        0
# pc5        0
# pc6        0
# pc7        0
# pc8        0
# pc9        0
# pc10       0
# pc11       0
# pc12       0
# pc13       0
# pc14       0
# pc15       0
# pc16       0
# label      0
# dtype: int64

# %% [markdown]
# ternyata tidak ada data yang null

# %% [markdown]
# ###Menghapus Duplikat pada Data

# %%
loan_activities.duplicated().sum()
# Out:
# 0

# %%
non_borrower_user.duplicated().sum()
# Out:
# 0

# %%
train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ternyata tidak ada duplikat

# %% [markdown]
# ###Menghapus Kolom dengan High Cardinality = "user_id"

# %%
copytrain.drop('user_id', axis = 1, inplace = True)

# %%
copytrain.head()
# Out:
#    pc0  pc1    pc2    pc3       pc4  pc5    pc6    pc7    pc8       pc9  pc10  \
# 0  1.0  1.0  0.275  0.255  0.927273  0.4  0.260  0.040  0.254  0.976923   1.0
# 1  0.0  0.0  0.430  0.365  0.848837  0.4  1.253  0.210  1.235  0.985634   1.0
# 2  1.0  3.0  1.315  0.825  0.627376  0.9  2.385  0.128  2.270  0.951782   1.0
# 3  0.0  5.0 -1.000 -1.000 -1.000000 -1.0 -1.000 -1.000 -1.000 -1.000000   0.0
# 4  1.0  1.0  0.235  0.160  0.680851  0.1  0.120  0.002  0.104  0.866667   0.0
#
#        pc11      pc12      pc13      pc14      pc15      pc16  label
# 0  0.072727  0.023077  0.078431  0.750000  0.018182  0.250000      0
# 1  0.151163  0.014366  0.054795  0.500000  0.011628  0.250000      0
# 2  0.372624  0.048218  0.054545  0.777778  0.003802  0.111111      0
# 3 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000      0
# 4  0.319149  0.133333  0.031250 -1.000000 -1.000000 -1.000000      0

# %% [markdown]
# ###Handling Imbalance pada Dataset "train.csv"

# %%
#Melihat Jumlah Fraud dan Nonfraud pada Dataset "train.csv"
train['label'].value_counts()
# Out:
# label
# 0    847042
# 1     10857
# Name: count, dtype: int64

# %% [markdown]
# ####Undersampling Label 0

# %%
#divide by class
train_0 = copytrain[copytrain['label'] == 0]
train_1 = copytrain[copytrain['label'] == 1]

#undersampling label 0 menjadi 10857
train_0 = train_0.sample(10857)
train_0.head()

train_under = pd.concat([train_0, train_1], axis = 0)
#print(train_under.label.value_counts())

#train_under.head()
train_under.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21714 entries, 433409 to 857789
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pc0     21714 non-null  float64
#  1   pc1     21714 non-null  float64
#  2   pc2     21714 non-null  float64
#  3   pc3     21714 non-null  float64
#  4   pc4     21714 non-null  float64
#  5   pc5     21714 non-null  float64
#  6   pc6     21714 non-null  float64
#  7   pc7     21714 non-null  float64
#  8   pc8     21714 non-null  float64
#  9   pc9     21714 non-null  float64
#  10  pc10    21714 non-null  float64
#  11  pc11    21714 non-null  float64
#  12  pc12    21714 non-null  float64
#  13  pc13    21714 non-null  float64
#  14  pc14    21714 non-null  float64
#  15  pc15    21714 non-null  float64
#  16  pc16    21714 non-null  float64
#  17  label   21714 non-null  int64
# dtypes: float64(17), int64(1)
# memory usage: 3.1 MB

# %%
train_under
# Out:
#         pc0  pc1    pc2    pc3       pc4  pc5    pc6    pc7    pc8       pc9  \
# 433409  1.0  1.0  0.320  0.280  0.875000  0.3  0.153  0.024  0.145  0.947712
# 708584  1.0  4.0 -1.000 -1.000 -1.000000 -1.0 -1.000 -1.000 -1.000 -1.000000
# 36192   1.0  5.0  1.615  1.490  0.922601  1.0  3.499  0.030  3.467  0.990855
# 835495  1.0  3.0 -1.000 -1.000 -1.000000 -1.0 -1.000 -1.000 -1.000 -1.000000
# 322088  0.0  2.0  0.260  0.195  0.750000  0.2  0.282  0.183  0.269  0.953901
# ...     ...  ...    ...    ...       ...  ...    ...    ...    ...       ...
# 857668  1.0  2.0 -1.000 -1.000 -1.000000 -1.0 -1.000 -1.000 -1.000 -1.000000
# 857678  1.0  5.0 -1.000 -1.000 -1.000000 -1.0 -1.000 -1.000 -1.000 -1.000000
# 857691  1.0  6.0 -1.000 -1.000 -1.000000 -1.0 -1.000 -1.000 -1.000 -1.000000
# 857775  1.0  6.0  0.590  0.575  0.974576  0.5  1.668  0.087  1.665  0.998201
# 857789  1.0  8.0 -1.000 -1.000 -1.000000 -1.0 -1.000 -1.000 -1.000 -1.000000
#
# ...

# %% [markdown]
# ####Oversampling Label 1 Menggunakan Metode SMOTE

# %%
from imblearn.over_sampling import SMOTE

SMOTE = SMOTE(sampling_strategy='minority')

X = train.drop('label', axis='columns')
y = train['label']

X_sm, y_sm = SMOTE.fit_resample(X,y)

y_sm.value_counts()
# Out:
# label
# 0    847042
# 1    847042
# Name: count, dtype: int64

# %%
y_sm.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: label, dtype: int64

# %%
X_sm.head()
# Out:
#    user_id  pc0  pc1    pc2    pc3       pc4  pc5    pc6    pc7    pc8  \
# 0        3  1.0  1.0  0.275  0.255  0.927273  0.4  0.260  0.040  0.254
# 1        5  0.0  0.0  0.430  0.365  0.848837  0.4  1.253  0.210  1.235
# 2        9  1.0  3.0  1.315  0.825  0.627376  0.9  2.385  0.128  2.270
# 3       10  0.0  5.0 -1.000 -1.000 -1.000000 -1.0 -1.000 -1.000 -1.000
# 4       17  1.0  1.0  0.235  0.160  0.680851  0.1  0.120  0.002  0.104
#
#         pc9  pc10      pc11      pc12      pc13      pc14      pc15      pc16
# 0  0.976923   1.0  0.072727  0.023077  0.078431  0.750000  0.018182  0.250000
# 1  0.985634   1.0  0.151163  0.014366  0.054795  0.500000  0.011628  0.250000
# 2  0.951782   1.0  0.372624  0.048218  0.054545  0.777778  0.003802  0.111111
# 3 -1.000000   0.0 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 4  0.866667   0.0  0.319149  0.133333  0.031250 -1.000000 -1.000000 -1.000000

# %%
train_sm = pd.concat([X_sm, y_sm], axis = 1)

# %%
train_sm.tail()
# Out:
#          user_id       pc0       pc1       pc2       pc3       pc4       pc5  \
# 1694079  3568790  0.486494  1.459483 -0.314470 -0.322172  0.004019 -0.332443
# 1694080  1468704  1.000000  1.065669 -1.000000 -1.000000 -1.000000 -1.000000
# 1694081  2279311  1.000000  0.235838 -1.000000 -1.000000 -1.000000 -1.000000
# 1694082  1085702  1.000000  5.870771 -0.961716 -0.962523 -0.939751 -0.951539
# 1694083  2517982  1.000000  5.748356 -0.438965 -0.500886 -0.374543 -0.399562
#
#               pc6       pc7       pc8       pc9      pc10      pc11      pc12  \
# 1694079 -0.436171 -0.484954 -0.437711  0.011292  0.513506 -0.463501 -0.470775
# 1694080 -1.000000 -1.000000 -1.000000 -1.000000  0.000000 -1.000000 -1.000000
# 1694081 -1.000000 -1.000000 -1.000000 -1.000000  0.000000 -1.000000 -1.000000
# 1694082 -0.964365 -0.967273 -0.964527 -0.936954  0.096922 -0.963327 -0.966124
# 1694083 -0.427707 -0.576316 -0.440842 -0.274470  0.000000 -0.499635 -0.599708
#
# ...

# %% [markdown]
# ###Normalisasi Max-Min Value pc0 - pc15 pada Dataset "train.csv"

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
# Pilih kolom yang ingin dinormalisasi
columns_to_scale = ['pc0', 'pc1', 'pc2', 'pc3', 'pc4', 'pc5', 'pc6', 'pc7', 'pc8', 'pc9', 'pc10', 'pc11', 'pc12', 'pc13', 'pc14', 'pc15']

# Terapkan MinMaxScaler hanya pada kolom tertentu
train[columns_to_scale] = scaler.fit_transform(train[columns_to_scale])

# %%
train.head()
# Out:
#    user_id  pc0       pc1       pc2       pc3       pc4       pc5       pc6  \
# 0        3  1.0  0.222222  0.011302  0.011158  0.963636  0.003061  0.019349
# 1        5  0.5  0.111111  0.012676  0.012136  0.924419  0.003061  0.034598
# 2        9  1.0  0.444444  0.020520  0.016226  0.813688  0.004155  0.051982
# 3       10  0.5  0.666667  0.000000  0.000000  0.000000  0.000000  0.000000
# 4       17  1.0  0.222222  0.010947  0.010313  0.840426  0.002405  0.017199
#
#         pc7       pc8       pc9      pc10      pc11      pc12      pc13  \
# 0  0.077973  0.019467  0.988462  0.000762  0.536364  0.511538  0.359477
# 1  0.090718  0.034696  0.992817  0.000762  0.575581  0.507183  0.351598
# 2  0.084570  0.050764  0.975891  0.000762  0.686312  0.524109  0.351515
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.075124  0.017139  0.933333  0.000000  0.659574  0.566667  0.343750
#
#        pc14      pc15      pc16  label
# ...

# %% [markdown]
# ###Normalisasi Max-Min Value pc0 - pc15 pada Dataset "test.csv"

# %% [markdown]
# ###Mengubah Seluruh Varian -1.0 dalam Dataset "train.csv" menjadi -1.0

# %% [markdown]
# belum berhasil :(

# %%
# Fungsi untuk mengganti semua variasi -1 menjadi -1.0
def replace_negative_one(val):
    try:
        if float(val) == -1.000:
            return -1.0
    except ValueError:
        pass
    return val

# Terapkan perubahan ke seluruh DataFrame
train = train.applymap(replace_negative_one)

# Konversi kolom ke tipe data yang sesuai jika diperlukan
#for col in train.columns:
#    train[col] = train[col].astype(float, errors='ignore')

# Simpan dataset yang sudah diperbaiki
#df.to_csv('path/to/your/updated_dataset.csv', index=False)

# %%
train.head()

# %% [markdown]
# ##**Eksplorasi Dataset**

# %% [markdown]
# ###Melihat Tipe Loan dan Jumlah Masing-Masing Tipe

# %%
loan_type_counts = loan_activities['loan_type'].value_counts()
loan_type_counts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9c60f8777065> in <cell line: 1>()
# ----> 1 loan_type_counts = loan_activities['loan_type'].value_counts()
#       2 loan_type_counts
#
# NameError: name 'loan_activities' is not defined

# %%
import matplotlib.pyplot as plt

plt.bar(loan_type_counts.index, loan_type_counts.values)
plt.xlabel('Category')
plt.ylabel('Counts')
plt.title('Category Frequency Bar Chart')
plt.xticks(rotation=45)  # Memutar label x agar tidak bertumpuk
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e937f0a105c4> in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.bar(loan_type_counts.index, loan_type_counts.values)
#       4 plt.xlabel('Category')
#       5 plt.ylabel('Counts')
#
# NameError: name 'loan_type_counts' is not defined

# %% [markdown]
# ###Apakah user_id yang Terdapat pada Dataset 'non_borrower_user' Ada Juga di Dataset 'train'

# %%
common_ids = non_borrower_user['user_id'].isin(train['user_id'])
print(non_borrower_user[common_ids])

# %%
filtered_train = train[train['user_id']==6]
filtered_train

# %%
filtered_non_borrower_user = non_borrower_user[non_borrower_user['user_id']==10]
filtered_non_borrower_user

# %% [markdown]
# Kesimpulan: non_borrower_user tidak digunakan untuk training model --> lalu untuk apa ada data non_borrower_user?

# %% [markdown]
# ###Apakah user_id yang Terdapat pada Dataset 'test' Ada Juga di Dataset 'train'

# %%
common_ids = test['user_id'].isin(train['user_id'])
print(test[common_ids])

# %%
test[test['user_id']==3699581]

# %% [markdown]
# Kesimpulan: test tidak ada dalam data train

# %% [markdown]
# ##**Membangun Model**

# %% [markdown]
# ###Decision Tree Classifier

# %% [markdown]
# **Menggunakan Dataset "train.csv"**

# %% [markdown]
# Membangun Model

# %%
#splitting the data
x = np.array(train[["user_id", "pc0", "pc1", "pc2", "pc3", "pc4", "pc5", "pc6", "pc7", "pc8", "pc9", "pc10", "pc11", "pc12", "pc13", "pc14", "pc15", "pc16"]])
y = np.array(train["label"])

# %%
#training a machine learning model using decision tree classifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)
model = DecisionTreeClassifier()
model.fit(xtrain, ytrain)
model.score(xtest, ytest)
# Out:
# 0.9741694836227999

# %% [markdown]
# Prediksi Data Testing

# %%
#import data testing
test = pd.read_csv('/content/drive/My Drive/PROJECT/DATATHON/DATASET/test.csv', sep=',')
test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a1bda978a804> in <cell line: 2>()
#       1 #import data testing
# ----> 2 test = pd.read_csv('/content/drive/My Drive/PROJECT/DATATHON/DATASET/test.csv', sep=',')
#       3 test.head()
#
# NameError: name 'pd' is not defined

# %%
x_testing = np.array(test[["user_id", "pc0", "pc1", "pc2", "pc3", "pc4", "pc5", "pc6", "pc7", "pc8", "pc9", "pc10", "pc11", "pc12", "pc13", "pc14", "pc15", "pc16"]])
prediksi_fraud = model.predict(x_testing)

test['label'] = prediksi_fraud
#test['label'] = test['label'].map({"No Fraud": 0, "Fraud": 1})

# %%
test.head()
# Out:
#    user_id  pc0  pc1    pc2    pc3       pc4  pc5    pc6    pc7    pc8  \
# 0        4  1.0  2.0 -1.000 -1.000 -1.000000 -1.0 -1.000 -1.000 -1.000
# 1       13  1.0  5.0  0.445  0.420  0.943820  0.8  0.783  0.234  0.778
# 2       37  1.0  6.0  1.680  1.080  0.642857  0.6  1.167  0.046  1.007
# 3       61  0.0  3.0  1.505  0.875  0.581395  0.9  0.425  0.012  0.286
# 4       66  1.0  5.0  2.210  1.075  0.486425  1.0  1.349  0.087  1.015
#
#         pc9  pc10      pc11      pc12      pc13      pc14      pc15      pc16  \
# 0 -1.000000   0.0 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 1  0.993614   2.0  0.056180  0.006386  0.095238  0.750000  0.022472  0.250000
# 2  0.862896   1.0  0.357143  0.137104  0.027778  0.500000  0.002976  0.166667
# 3  0.672941   1.0  0.418605  0.327059  0.051429  0.333333  0.003322  0.111111
# 4  0.752409   2.0  0.513575  0.247591  0.046512  0.800000  0.004525  0.200000
#
#    label
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
kolom_terpilih = ['user_id', 'label']
result = test[kolom_terpilih]

result.head()
# Out:
#    user_id  label
# 0        4      0
# 1       13      0
# 2       37      0
# 3       61      0
# 4       66      0

# %%
result.to_csv('result.csv', index=False)

from google.colab import files
files.download('result.csv')

# %% [markdown]
# **Menggunakan Dataset "train_under.csv"**

# %%
#splitting the data
x = np.array(train_under[["user_id", "pc0", "pc1", "pc2", "pc3", "pc4", "pc5", "pc6", "pc7", "pc8", "pc9", "pc10", "pc11", "pc12", "pc13", "pc14", "pc15", "pc16"]])
y = np.array(train_under["label"])

# %%
#training a machine learning model using decision tree classifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)
model = DecisionTreeClassifier()
model.fit(xtrain, ytrain)
model.score(xtest, ytest)
# Out:
# 0.5908358277688234

# %%
#import data testing
test = pd.read_csv('/content/drive/My Drive/PROJECT/DATATHON/DATASET/test.csv', sep=',')
test.head()
# Out:
#    user_id  pc0  pc1    pc2    pc3       pc4  pc5    pc6    pc7    pc8  \
# 0        4  1.0  2.0 -1.000 -1.000 -1.000000 -1.0 -1.000 -1.000 -1.000
# 1       13  1.0  5.0  0.445  0.420  0.943820  0.8  0.783  0.234  0.778
# 2       37  1.0  6.0  1.680  1.080  0.642857  0.6  1.167  0.046  1.007
# 3       61  0.0  3.0  1.505  0.875  0.581395  0.9  0.425  0.012  0.286
# 4       66  1.0  5.0  2.210  1.075  0.486425  1.0  1.349  0.087  1.015
#
#         pc9  pc10      pc11      pc12      pc13      pc14      pc15      pc16
# 0 -1.000000   0.0 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 1  0.993614   2.0  0.056180  0.006386  0.095238  0.750000  0.022472  0.250000
# 2  0.862896   1.0  0.357143  0.137104  0.027778  0.500000  0.002976  0.166667
# 3  0.672941   1.0  0.418605  0.327059  0.051429  0.333333  0.003322  0.111111
# 4  0.752409   2.0  0.513575  0.247591  0.046512  0.800000  0.004525  0.200000

# %%
x_testing = np.array(test[["user_id", "pc0", "pc1", "pc2", "pc3", "pc4", "pc5", "pc6", "pc7", "pc8", "pc9", "pc10", "pc11", "pc12", "pc13", "pc14", "pc15", "pc16"]])
prediksi_fraud = model.predict(x_testing)

test['label'] = prediksi_fraud
#test['label'] = test['label'].map({"No Fraud": 0, "Fraud": 1})

# %%
kolom_terpilih = ['user_id', 'label']
result = test[kolom_terpilih]

result.head()
# Out:
#    user_id  label
# 0        4      1
# 1       13      0
# 2       37      0
# 3       61      0
# 4       66      0

# %%
result.to_csv('result.csv', index=False)

from google.colab import files
files.download('result.csv')

# %% [markdown]
# **Menggunakan Dataset "train_sm.csv"**

# %%
#splitting the data
x = np.array(train_sm[["user_id", "pc0", "pc1", "pc2", "pc3", "pc4", "pc5", "pc6", "pc7", "pc8", "pc9", "pc10", "pc11", "pc12", "pc13", "pc14", "pc15", "pc16"]])
y = np.array(train_sm["label"])

# %%
#training a machine learning model using decision tree classifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)
model = DecisionTreeClassifier()
model.fit(xtrain, ytrain)
model.score(xtest, ytest)
# Out:
# 0.9814531148082889

# %%
#import data testing
test = pd.read_csv('/content/drive/My Drive/PROJECT/DATATHON/DATASET/test.csv', sep=',')
test.head()
# Out:
#    user_id  pc0  pc1    pc2    pc3       pc4  pc5    pc6    pc7    pc8  \
# 0        4  1.0  2.0 -1.000 -1.000 -1.000000 -1.0 -1.000 -1.000 -1.000
# 1       13  1.0  5.0  0.445  0.420  0.943820  0.8  0.783  0.234  0.778
# 2       37  1.0  6.0  1.680  1.080  0.642857  0.6  1.167  0.046  1.007
# 3       61  0.0  3.0  1.505  0.875  0.581395  0.9  0.425  0.012  0.286
# 4       66  1.0  5.0  2.210  1.075  0.486425  1.0  1.349  0.087  1.015
#
#         pc9  pc10      pc11      pc12      pc13      pc14      pc15      pc16
# 0 -1.000000   0.0 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 1  0.993614   2.0  0.056180  0.006386  0.095238  0.750000  0.022472  0.250000
# 2  0.862896   1.0  0.357143  0.137104  0.027778  0.500000  0.002976  0.166667
# 3  0.672941   1.0  0.418605  0.327059  0.051429  0.333333  0.003322  0.111111
# 4  0.752409   2.0  0.513575  0.247591  0.046512  0.800000  0.004525  0.200000

# %%
test.isnull().sum()
# Out:
# user_id    0
# pc0        0
# pc1        0
# pc2        0
# pc3        0
# pc4        0
# pc5        0
# pc6        0
# pc7        0
# pc8        0
# pc9        0
# pc10       0
# pc11       0
# pc12       0
# pc13       0
# pc14       0
# pc15       0
# pc16       0
# dtype: int64

# %%
x_testing = np.array(test[["user_id", "pc0", "pc1", "pc2", "pc3", "pc4", "pc5", "pc6", "pc7", "pc8", "pc9", "pc10", "pc11", "pc12", "pc13", "pc14", "pc15", "pc16"]])
prediksi_fraud = model.predict(x_testing)

test['label'] = prediksi_fraud
#test['label'] = test['label'].map({"No Fraud": 0, "Fraud": 1})

# %%
kolom_terpilih = ['user_id', 'label']
result = test[kolom_terpilih]

result.head()
# Out:
#    user_id  label
# 0        4      0
# 1       13      0
# 2       37      0
# 3       61      0
# 4       66      0

# %%
result.to_csv('result.csv', index=False)

from google.colab import files
files.download('result.csv')

# %% [markdown]
# NOTES
# - if we have missing value but don't want to drop it, impute dengan 'Missing' atau indikator lainnya

# %% [markdown]
# TO DO Sebelum Membangun Model
# - drop user_id karena tidak dibutuhkan ketika melatih model, hanya dibutuhkan ketika membuat prediksi
# - karena data kita punya banyak atribut (pc0 - pc16) maka lakukan PCA untuk mengurangi dimensi --> jangan lupa terapkan hal yang sama jg pada data testing utk memastikan bahwa data testing diproyeksikan ke dalam ruang komponen utama yang sama dengan data training
# - skalasi data numerik --> bisa StandardScalaation, bisa Min-Max, terserah
# - handling highly correlated variables

# %% [markdown]
# ###Random Forest

# %% [markdown]
# ####Split Data into Training and Testing

# %%
#Drop identifier column
X = copytrain.drop('label', axis=1)

#one hot encode
X = pd.get_dummies(X)

#create target columns
y = copytrain['label']

# %%
#create testing and training partitions
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %% [markdown]
# ####Setup ML Pipelines

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
pipelines = {
    'rf' : make_pipeline(StandardScaler(), RandomForestClassifier(random_state=1234)),
}

# %%
grid = {
  'rf' : {
    'randomforestclassifier__n_estimators':[100,200,300]
  },
}

# %%
pipelines.items()
# Out:
# dict_items([('rf', Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(random_state=1234))]))])

# %%
#create a blank dictionary to hold the models
fit_models = {}

#loop through all the algos
for algo, pipeline in pipelines.items():
  print(f'Training the {algo} model')
  #create new grid Search CV class
  model = GridSearchCV(pipeline, grid[algo], n_jobs=-1, cv=10)
  #train the model
  model.fit(X_train, y_train)
  #store results inside of the dictionary
  fit_models[algo] = model
# Out:
# Training the rf model

# %% [markdown]
# ####Evaluate Performance on Testing Data

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
#evaluate the performance of the model
for algo, model in fit_models.items():
  yhat = model.predict(X_test)
  accuracy = accuracy_score(y_test, yhat)
  precision = precision_score(y_test, yhat)
  recall = recall_score(y_test, yhat)
  print(f'Metrics for {algo}: accuracy- {accuracy}, recall- {recall}, precision- {precision}')
# Out:
# Metrics for rf: accuracy- 0.9874422038310603, recall- 0.00031026993484331366, precision- 0.09090909090909091

# %% [markdown]
# ####Save Best Model

# %%
import pickle

# %%
with open('rf_model.pkl', 'wb') as f:
  pickle.dump(fit_models['rf'], f)

# %%
with open('rf_model.pkl', 'rb') as f:
  reloaded_model = pickle.load(f)

# %% [markdown]
# ####Predict on Test Data

# %%
#import data testing
test = pd.read_csv('/content/drive/My Drive/PROJECT/DATATHON/DATASET/test.csv', sep=',')
test.head()
copytest = test.copy()

# %%
#one-hot encode categorical variables
copytest = pd.get_dummies(copytest.drop('user_id', axis=1))

# %%
yhat_test = fit_models['rf'].predict(copytest) #rf atau gb, cari yang the best

# %% [markdown]
# ####Make Submission

# %%
submission = pd.DataFrame([test['user_id'], yhat_test]).T
submission.columns = ['user_id', 'label']
submission.head()
# Out:
#    user_id  label
# 0        4      0
# 1       13      0
# 2       37      0
# 3       61      0
# 4       66      0

# %%
submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367702 entries, 0 to 367701
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   user_id  367702 non-null  int64
#  1   label    367702 non-null  int64
# dtypes: int64(2)
# memory usage: 5.6 MB

# %%
submission.to_csv('submission.csv', index=False)

# %% [markdown]
# ###Gradient Boosting

# %% [markdown]
# ####Setup ML Pipelines

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier

# %%
pipelines = {
    'gb' : make_pipeline(StandardScaler(), GradientBoostingClassifier(random_state=1234))
}

# %%
GradientBoostingClassifier().get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.1,
#  'loss': 'log_loss',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_iter_no_change': None,
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
grid = {
  'gb' : {
    'gradientboostingclassifier__n_estimators':[100,200,300]
  }
}

# %%
pipelines.items()
# Out:
# dict_items([('gb', Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingclassifier',
#                  GradientBoostingClassifier(random_state=1234))]))])

# %%
#create a blank dictionary to hold the models
fit_models = {}

#loop through all the algos
for algo, pipeline in pipelines.items():
  print(f'Training the {algo} model')
  #create new grid Search CV class
  model = GridSearchCV(pipeline, grid[algo], n_jobs=-1, cv=10)
  #train the model
  model.fit(X_train, y_train)
  #store results inside of the dictionary
  fit_models[algo] = model
# Out:
# Training the gb model

# %% [markdown]
# ####Evaluate Performance on Testing Data

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
#evaluate the performance of the model
for algo, model in fit_models.items():
  yhat = model.predict(X_test)
  accuracy = accuracy_score(y_test, yhat)
  precision = precision_score(y_test, yhat)
  recall = recall_score(y_test, yhat)
  print(f'Metrics for {algo}: accuracy- {accuracy}, recall- {recall}, precision- {precision}')
# Out:
# Metrics for gb: accuracy- 0.9874188910906477, recall- 0.00031026993484331366, precision- 0.058823529411764705

# %% [markdown]
# ####Save Best Model

# %%
import pickle

# %%
with open('gb_model.pkl', 'wb') as f:
  pickle.dump(fit_models['gb'], f)
with open('gb_model.pkl', 'rb') as f:
  reloaded_model = pickle.load(f)

# %% [markdown]
# ####Predict on Test Data

# %%
#import data testing
test = pd.read_csv('/content/drive/My Drive/PROJECT/DATATHON/DATASET/test.csv', sep=',')
test.head()
copytest = test.copy()

# %%
#one-hot encode categorical variables
copytest = pd.get_dummies(copytest.drop('user_id', axis=1))

# %%
yhat_test = fit_models['gb'].predict(copytest) #rf atau gb, cari yang the best

# %% [markdown]
# ####Make Submission

# %%
submission = pd.DataFrame([test['user_id'], yhat_test]).T
submission.columns = ['user_id', 'label']
submission.head()
# Out:
#    user_id  label
# 0        4      0
# 1       13      0
# 2       37      0
# 3       61      0
# 4       66      0

# %%
submission.to_csv('submission (1).csv', index=False)
